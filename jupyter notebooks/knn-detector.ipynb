# %% [markdown]
# # Machine Learning Emotion Detection

# %% [markdown]
# ## 1. Load modules

# %%
import cv2 as cv
import numpy as np
from os import listdir, walk
from os.path import isfile, join

from pathlib import Path


from sklearn import tree

# %% [markdown]
# ## 2. Load Images

# %%
def walk_through_dir(dir_path: Path) -> dict:
    """Prints dir_path content"""
    counts = dict()
    classes = dict()
    i=-1
    for dirpath, dirnames, filenames in walk(dir_path):
        i = i+1
        print(f"There are {len(dirnames)} directiories and {len(filenames)} images in '{dirpath}' folder ")
        if (i>0):
            c = dirpath.split('\\')
            counts[c[-1]] = len(filenames)
            classes[c[-1]] = i
    return (counts, classes)

# %%
data_path = Path("Kaggle/CV/Emotions_detection")
images_path = data_path / "emotions_dataset"
train_path = images_path / "train"
test_path = images_path / "test"

ctrain, classes = walk_through_dir(train_path)
ctest, _ = walk_through_dir(test_path)

# %%
def make_datasets(counts, dataset_type, path, upscale = ""):
    x = []
    y = []

    for label, count in counts.items():
        for i in range(0, count):
            suffix = f"{dataset_type}/{label}/im{i}.png" if upscale == "" else f"{dataset_type}/{label}/im{i}_{upscale}.png"
            print(path / suffix)
            img = cv.imread(path / suffix)
            img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
            if type(img) is None:
                print("ALOOOOOOOO")
            x.append(img)
            y.append(label)

            # if i==0: 
            #     cv.imshow(mat=img, winname="asdfghjklasdfghjkl")
            #     cv.waitKey(0)
            #     cv.destroyAllWindows()
    x = np.array(x).astype(np.float32)
    x = x.reshape(x.shape[0], (x.shape[1]*x.shape[2]))
    return (x, y)

# %%
x_train, y_tr = make_datasets(ctrain, "train", images_path)
x_test, y_te = make_datasets(ctest, "test", images_path)



print(len(x_train))
print(len(x_test))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 x_train, y_tr = make_datasets(ctrain, "train", images_path)
#       2 x_test, y_te = make_datasets(ctest, "test", images_path)
#       6 print(len(x_train))
#
# Cell In[23], line 8, in make_datasets(counts, dataset_type, path)
#       6 for i in range(0, count):
#       7     img = cv.imread(path / f"{dataset_type}/{label}/im{i}.png")
# ----> 8     img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
#       9     if type(img) is None:
#      10         print("ALOOOOOOOO")
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
print(classes)

def replace_label(y):
    y_new = [classes[label] for label in y]
    return np.array(y_new)

y_train = replace_label(y_tr)
y_test  = replace_label(y_te)

print(y_train)
# Out:
# {'angry': 1, 'disgusted': 2, 'fearful': 3, 'happy': 4, 'neutral': 5, 'sad': 6, 'surprised': 7}
# [1. 1. 1. ... 7. 7. 7.]

# %%
x_train.shape
# Out:
# (28709, 2304)

# %% [markdown]
# #### Upscaled data

# %%
data_path = Path("upscaled_images")
images_path = data_path
train_path = images_path / "train"
test_path = images_path / "test"

ctrain, classes = walk_through_dir(train_path)
ctest, _ = walk_through_dir(test_path)
# Out:
# There are 7 directiories and 0 images in 'upscaled_images\train' folder
# There are 0 directiories and 3995 images in 'upscaled_images\train\angry' folder
# There are 0 directiories and 436 images in 'upscaled_images\train\disgusted' folder
# There are 0 directiories and 4097 images in 'upscaled_images\train\fearful' folder
# There are 0 directiories and 7215 images in 'upscaled_images\train\happy' folder
# There are 0 directiories and 4965 images in 'upscaled_images\train\neutral' folder
# There are 0 directiories and 4830 images in 'upscaled_images\train\sad' folder
# There are 0 directiories and 3171 images in 'upscaled_images\train\surprised' folder
# There are 7 directiories and 0 images in 'upscaled_images\test' folder
# There are 0 directiories and 958 images in 'upscaled_images\test\angry' folder
# There are 0 directiories and 111 images in 'upscaled_images\test\disgusted' folder
# There are 0 directiories and 1024 images in 'upscaled_images\test\fearful' folder
# There are 0 directiories and 1774 images in 'upscaled_images\test\happy' folder
# There are 0 directiories and 1233 images in 'upscaled_images\test\neutral' folder
# There are 0 directiories and 1247 images in 'upscaled_images\test\sad' folder
# There are 0 directiories and 831 images in 'upscaled_images\test\surprised' folder

# %%
x_train, y_tr = make_datasets(ctrain, "train", images_path, 4)
x_test, y_te = make_datasets(ctest, "test", images_path, 4)

print(len(x_train))
print(len(x_test))

print(classes)

def replace_label(y):
    y_new = [classes[label] for label in y]
    return np.array(y_new)

y_train = replace_label(y_tr)
y_test  = replace_label(y_te)

print(y_train)
# Out:
# upscaled_images\train\angry\im0_4.png
# upscaled_images\train\angry\im1_4.png
# upscaled_images\train\angry\im2_4.png
# upscaled_images\train\angry\im3_4.png
# upscaled_images\train\angry\im4_4.png
# upscaled_images\train\angry\im5_4.png
# upscaled_images\train\angry\im6_4.png
# upscaled_images\train\angry\im7_4.png
# upscaled_images\train\angry\im8_4.png
# upscaled_images\train\angry\im9_4.png
# upscaled_images\train\angry\im10_4.png
# upscaled_images\train\angry\im11_4.png
# upscaled_images\train\angry\im12_4.png
# upscaled_images\train\angry\im13_4.png
# upscaled_images\train\angry\im14_4.png
# upscaled_images\train\angry\im15_4.png
# upscaled_images\train\angry\im16_4.png
# upscaled_images\train\angry\im17_4.png
# upscaled_images\train\angry\im18_4.png
# upscaled_images\train\angry\im19_4.png
# upscaled_images\train\angry\im20_4.png
# upscaled_images\train\angry\im21_4.png
# upscaled_images\train\angry\im22_4.png
# upscaled_images\train\angry\im23_4.png
# upscaled_images\train\angry\im24_4.png
# upscaled_images\train\angry\im25_4.png
# upscaled_images\train\angry\im26_4.png
# upscaled_images\train\angry\im27_4.png
# upscaled_images\train\angry\im28_4.png
# upscaled_images\train\angry\im29_4.png
# upscaled_images\train\angry\im30_4.png
# upscaled_images\train\angry\im31_4.png
# upscaled_images\train\angry\im32_4.png
# upscaled_images\train\angry\im33_4.png
# upscaled_images\train\angry\im34_4.png
# upscaled_images\train\angry\im35_4.png
# upscaled_images\train\angry\im36_4.png
# upscaled_images\train\angry\im37_4.png
# upscaled_images\train\angry\im38_4.png
# upscaled_images\train\angry\im39_4.png
# upscaled_images\train\angry\im40_4.png
# upscaled_images\train\angry\im41_4.png
# upscaled_images\train\angry\im42_4.png
# upscaled_images\train\angry\im43_4.png
# upscaled_images\train\angry\im44_4.png
# upscaled_images\train\angry\im45_4.png
# upscaled_images\train\angry\im46_4.png
# upscaled_images\train\angry\im47_4.png
# upscaled_images\train\angry\im48_4.png
# upscaled_images\train\angry\im49_4.png
# upscaled_images\train\angry\im50_4.png
# upscaled_images\train\angry\im51_4.png
# upscaled_images\train\angry\im52_4.png
# upscaled_images\train\angry\im53_4.png
# upscaled_images\train\angry\im54_4.png
# upscaled_images\train\angry\im55_4.png
# upscaled_images\train\angry\im56_4.png
# upscaled_images\train\angry\im57_4.png
# upscaled_images\train\angry\im58_4.png
# upscaled_images\train\angry\im59_4.png
# upscaled_images\train\angry\im60_4.png
# upscaled_images\train\angry\im61_4.png
# upscaled_images\train\angry\im62_4.png
# upscaled_images\train\angry\im63_4.png
# upscaled_images\train\angry\im64_4.png
# upscaled_images\train\angry\im65_4.png
# upscaled_images\train\angry\im66_4.png
# upscaled_images\train\angry\im67_4.png
# upscaled_images\train\angry\im68_4.png
# upscaled_images\train\angry\im69_4.png
# upscaled_images\train\angry\im70_4.png
# upscaled_images\train\angry\im71_4.png
# upscaled_images\train\angry\im72_4.png
# upscaled_images\train\angry\im73_4.png
# upscaled_images\train\angry\im74_4.png
# upscaled_images\train\angry\im75_4.png
# upscaled_images\train\angry\im76_4.png
# upscaled_images\train\angry\im77_4.png
# upscaled_images\train\angry\im78_4.png
# upscaled_images\train\angry\im79_4.png
# upscaled_images\train\angry\im80_4.png
# upscaled_images\train\angry\im81_4.png
# upscaled_images\train\angry\im82_4.png
# upscaled_images\train\angry\im83_4.png
# upscaled_images\train\angry\im84_4.png
# upscaled_images\train\angry\im85_4.png
# upscaled_images\train\angry\im86_4.png
# upscaled_images\train\angry\im87_4.png
# upscaled_images\train\angry\im88_4.png
# upscaled_images\train\angry\im89_4.png
# upscaled_images\train\angry\im90_4.png
# upscaled_images\train\angry\im91_4.png
# upscaled_images\train\angry\im92_4.png
# upscaled_images\train\angry\im93_4.png
# upscaled_images\train\angry\im94_4.png
# upscaled_images\train\angry\im95_4.png
# upscaled_images\train\angry\im96_4.png
# upscaled_images\train\angry\im97_4.png
# upscaled_images\train\angry\im98_4.png
# upscaled_images\train\angry\im99_4.png
# upscaled_images\train\angry\im100_4.png
# upscaled_images\train\angry\im101_4.png
# upscaled_images\train\angry\im102_4.png
# upscaled_images\train\angry\im103_4.png
# upscaled_images\train\angry\im104_4.png
# upscaled_images\train\angry\im105_4.png
# upscaled_images\train\angry\im106_4.png
# upscaled_images\train\angry\im107_4.png
# upscaled_images\train\angry\im108_4.png
# upscaled_images\train\angry\im109_4.png
# upscaled_images\train\angry\im110_4.png
# upscaled_images\train\angry\im111_4.png
# upscaled_images\train\angry\im112_4.png
# upscaled_images\train\angry\im113_4.png
# upscaled_images\train\angry\im114_4.png
# upscaled_images\train\angry\im115_4.png
# upscaled_images\train\angry\im116_4.png
# upscaled_images\train\angry\im117_4.png
# upscaled_images\train\angry\im118_4.png
# upscaled_images\train\angry\im119_4.png
# upscaled_images\train\angry\im120_4.png
# upscaled_images\train\angry\im121_4.png
# upscaled_images\train\angry\im122_4.png
# upscaled_images\train\angry\im123_4.png
# upscaled_images\train\angry\im124_4.png
# upscaled_images\train\angry\im125_4.png
# upscaled_images\train\angry\im126_4.png
# upscaled_images\train\angry\im127_4.png
# upscaled_images\train\angry\im128_4.png
# upscaled_images\train\angry\im129_4.png
# upscaled_images\train\angry\im130_4.png
# upscaled_images\train\angry\im131_4.png
# upscaled_images\train\angry\im132_4.png
# upscaled_images\train\angry\im133_4.png
# upscaled_images\train\angry\im134_4.png
# upscaled_images\train\angry\im135_4.png
# upscaled_images\train\angry\im136_4.png
# upscaled_images\train\angry\im137_4.png
# upscaled_images\train\angry\im138_4.png
# upscaled_images\train\angry\im139_4.png
# upscaled_images\train\angry\im140_4.png
# upscaled_images\train\angry\im141_4.png
# upscaled_images\train\angry\im142_4.png
# upscaled_images\train\angry\im143_4.png
# upscaled_images\train\angry\im144_4.png
# upscaled_images\train\angry\im145_4.png
# upscaled_images\train\angry\im146_4.png
# upscaled_images\train\angry\im147_4.png
# upscaled_images\train\angry\im148_4.png
# upscaled_images\train\angry\im149_4.png
# upscaled_images\train\angry\im150_4.png
# upscaled_images\train\angry\im151_4.png
# upscaled_images\train\angry\im152_4.png
# upscaled_images\train\angry\im153_4.png
# upscaled_images\train\angry\im154_4.png
# upscaled_images\train\angry\im155_4.png
# upscaled_images\train\angry\im156_4.png
# upscaled_images\train\angry\im157_4.png
# upscaled_images\train\angry\im158_4.png
# upscaled_images\train\angry\im159_4.png
# upscaled_images\train\angry\im160_4.png
# upscaled_images\train\angry\im161_4.png
# upscaled_images\train\angry\im162_4.png
# upscaled_images\train\angry\im163_4.png
# upscaled_images\train\angry\im164_4.png
# upscaled_images\train\angry\im165_4.png
# upscaled_images\train\angry\im166_4.png
# upscaled_images\train\angry\im167_4.png
# upscaled_images\train\angry\im168_4.png
# upscaled_images\train\angry\im169_4.png
# upscaled_images\train\angry\im170_4.png
# upscaled_images\train\angry\im171_4.png
# upscaled_images\train\angry\im172_4.png
# upscaled_images\train\angry\im173_4.png
# upscaled_images\train\angry\im174_4.png
# upscaled_images\train\angry\im175_4.png
# upscaled_images\train\angry\im176_4.png
# upscaled_images\train\angry\im177_4.png
# upscaled_images\train\angry\im178_4.png
# upscaled_images\train\angry\im179_4.png
# upscaled_images\train\angry\im180_4.png
# upscaled_images\train\angry\im181_4.png
# upscaled_images\train\angry\im182_4.png
# upscaled_images\train\angry\im183_4.png
# upscaled_images\train\angry\im184_4.png
# upscaled_images\train\angry\im185_4.png
# upscaled_images\train\angry\im186_4.png
# upscaled_images\train\angry\im187_4.png
# upscaled_images\train\angry\im188_4.png
# upscaled_images\train\angry\im189_4.png
# upscaled_images\train\angry\im190_4.png
# upscaled_images\train\angry\im191_4.png
# upscaled_images\train\angry\im192_4.png
# upscaled_images\train\angry\im193_4.png
# upscaled_images\train\angry\im194_4.png
# upscaled_images\train\angry\im195_4.png
# upscaled_images\train\angry\im196_4.png
# upscaled_images\train\angry\im1177_4.png
# upscaled_images\train\angry\im1178_4.png
# upscaled_images\train\angry\im1179_4.png
# upscaled_images\train\angry\im1180_4.png
# upscaled_images\train\angry\im1181_4.png
# upscaled_images\train\angry\im1182_4.png
# upscaled_images\train\angry\im1183_4.png
# upscaled_images\train\angry\im1184_4.png
# upscaled_images\train\angry\im1185_4.png
# upscaled_images\train\angry\im1186_4.png
# upscaled_images\train\angry\im1187_4.png
# upscaled_images\train\angry\im1188_4.png
# upscaled_images\train\angry\im1189_4.png
# upscaled_images\train\angry\im1190_4.png
# upscaled_images\train\angry\im1191_4.png
# upscaled_images\train\angry\im1192_4.png
# upscaled_images\train\angry\im1193_4.png
# upscaled_images\train\angry\im1194_4.png
# upscaled_images\train\angry\im1195_4.png
# upscaled_images\train\angry\im1196_4.png
# ...
# upscaled_images\test\surprised\im462_4.png
# upscaled_images\test\surprised\im463_4.png
# upscaled_images\test\surprised\im464_4.png
# upscaled_images\test\surprised\im465_4.png
# upscaled_images\test\surprised\im466_4.png
# upscaled_images\test\surprised\im467_4.png
# upscaled_images\test\surprised\im468_4.png
# upscaled_images\test\surprised\im469_4.png
# upscaled_images\test\surprised\im470_4.png
# upscaled_images\test\surprised\im471_4.png
# upscaled_images\test\surprised\im472_4.png
# upscaled_images\test\surprised\im473_4.png
# upscaled_images\test\surprised\im474_4.png
# upscaled_images\test\surprised\im475_4.png
# upscaled_images\test\surprised\im476_4.png
# upscaled_images\test\surprised\im477_4.png
# upscaled_images\test\surprised\im478_4.png
# upscaled_images\test\surprised\im479_4.png
# upscaled_images\test\surprised\im480_4.png
# upscaled_images\test\surprised\im481_4.png
# upscaled_images\test\surprised\im482_4.png
# upscaled_images\test\surprised\im483_4.png
# upscaled_images\test\surprised\im484_4.png
# upscaled_images\test\surprised\im485_4.png
# upscaled_images\test\surprised\im486_4.png
# upscaled_images\test\surprised\im487_4.png
# upscaled_images\test\surprised\im488_4.png
# upscaled_images\test\surprised\im489_4.png
# upscaled_images\test\surprised\im490_4.png
# upscaled_images\test\surprised\im491_4.png
# upscaled_images\test\surprised\im492_4.png
# upscaled_images\test\surprised\im493_4.png
# upscaled_images\test\surprised\im494_4.png
# upscaled_images\test\surprised\im495_4.png
# upscaled_images\test\surprised\im496_4.png
# upscaled_images\test\surprised\im497_4.png
# upscaled_images\test\surprised\im498_4.png
# upscaled_images\test\surprised\im499_4.png
# upscaled_images\test\surprised\im500_4.png
# upscaled_images\test\surprised\im501_4.png
# upscaled_images\test\surprised\im502_4.png
# upscaled_images\test\surprised\im503_4.png
# upscaled_images\test\surprised\im504_4.png
# upscaled_images\test\surprised\im505_4.png
# upscaled_images\test\surprised\im506_4.png
# upscaled_images\test\surprised\im507_4.png
# upscaled_images\test\surprised\im508_4.png
# upscaled_images\test\surprised\im509_4.png
# upscaled_images\test\surprised\im510_4.png
# upscaled_images\test\surprised\im511_4.png
# upscaled_images\test\surprised\im512_4.png
# upscaled_images\test\surprised\im513_4.png
# upscaled_images\test\surprised\im514_4.png
# upscaled_images\test\surprised\im515_4.png
# upscaled_images\test\surprised\im516_4.png
# upscaled_images\test\surprised\im517_4.png
# upscaled_images\test\surprised\im518_4.png
# upscaled_images\test\surprised\im519_4.png
# upscaled_images\test\surprised\im520_4.png
# upscaled_images\test\surprised\im521_4.png
# upscaled_images\test\surprised\im522_4.png
# upscaled_images\test\surprised\im523_4.png
# upscaled_images\test\surprised\im524_4.png
# upscaled_images\test\surprised\im525_4.png
# upscaled_images\test\surprised\im526_4.png
# upscaled_images\test\surprised\im527_4.png
# upscaled_images\test\surprised\im528_4.png
# upscaled_images\test\surprised\im529_4.png
# upscaled_images\test\surprised\im530_4.png
# upscaled_images\test\surprised\im531_4.png
# upscaled_images\test\surprised\im532_4.png
# upscaled_images\test\surprised\im533_4.png
# upscaled_images\test\surprised\im534_4.png
# upscaled_images\test\surprised\im535_4.png
# upscaled_images\test\surprised\im536_4.png
# upscaled_images\test\surprised\im537_4.png
# upscaled_images\test\surprised\im538_4.png
# upscaled_images\test\surprised\im539_4.png
# upscaled_images\test\surprised\im540_4.png
# upscaled_images\test\surprised\im541_4.png
# upscaled_images\test\surprised\im542_4.png
# upscaled_images\test\surprised\im543_4.png
# upscaled_images\test\surprised\im544_4.png
# upscaled_images\test\surprised\im545_4.png
# upscaled_images\test\surprised\im546_4.png
# upscaled_images\test\surprised\im547_4.png
# upscaled_images\test\surprised\im548_4.png
# upscaled_images\test\surprised\im549_4.png
# upscaled_images\test\surprised\im550_4.png
# upscaled_images\test\surprised\im551_4.png
# upscaled_images\test\surprised\im552_4.png
# upscaled_images\test\surprised\im553_4.png
# upscaled_images\test\surprised\im554_4.png
# upscaled_images\test\surprised\im555_4.png
# upscaled_images\test\surprised\im556_4.png
# upscaled_images\test\surprised\im557_4.png
# upscaled_images\test\surprised\im558_4.png
# upscaled_images\test\surprised\im559_4.png
# upscaled_images\test\surprised\im560_4.png
# upscaled_images\test\surprised\im561_4.png
# upscaled_images\test\surprised\im562_4.png
# upscaled_images\test\surprised\im563_4.png
# upscaled_images\test\surprised\im564_4.png
# upscaled_images\test\surprised\im565_4.png
# upscaled_images\test\surprised\im566_4.png
# upscaled_images\test\surprised\im567_4.png
# upscaled_images\test\surprised\im568_4.png
# upscaled_images\test\surprised\im569_4.png
# upscaled_images\test\surprised\im570_4.png
# upscaled_images\test\surprised\im571_4.png
# upscaled_images\test\surprised\im572_4.png
# upscaled_images\test\surprised\im573_4.png
# upscaled_images\test\surprised\im574_4.png
# upscaled_images\test\surprised\im575_4.png
# upscaled_images\test\surprised\im576_4.png
# upscaled_images\test\surprised\im577_4.png
# upscaled_images\test\surprised\im578_4.png
# upscaled_images\test\surprised\im579_4.png
# upscaled_images\test\surprised\im580_4.png
# upscaled_images\test\surprised\im581_4.png
# upscaled_images\test\surprised\im582_4.png
# upscaled_images\test\surprised\im583_4.png
# upscaled_images\test\surprised\im584_4.png
# upscaled_images\test\surprised\im585_4.png
# upscaled_images\test\surprised\im586_4.png
# upscaled_images\test\surprised\im587_4.png
# upscaled_images\test\surprised\im588_4.png
# upscaled_images\test\surprised\im589_4.png
# upscaled_images\test\surprised\im590_4.png
# upscaled_images\test\surprised\im591_4.png
# upscaled_images\test\surprised\im592_4.png
# upscaled_images\test\surprised\im593_4.png
# upscaled_images\test\surprised\im594_4.png
# upscaled_images\test\surprised\im595_4.png
# upscaled_images\test\surprised\im596_4.png
# upscaled_images\test\surprised\im597_4.png
# upscaled_images\test\surprised\im598_4.png
# upscaled_images\test\surprised\im599_4.png
# upscaled_images\test\surprised\im600_4.png
# upscaled_images\test\surprised\im601_4.png
# upscaled_images\test\surprised\im602_4.png
# upscaled_images\test\surprised\im603_4.png
# upscaled_images\test\surprised\im604_4.png
# upscaled_images\test\surprised\im605_4.png
# upscaled_images\test\surprised\im606_4.png
# upscaled_images\test\surprised\im607_4.png
# upscaled_images\test\surprised\im608_4.png
# upscaled_images\test\surprised\im609_4.png
# upscaled_images\test\surprised\im610_4.png
# upscaled_images\test\surprised\im611_4.png
# upscaled_images\test\surprised\im612_4.png
# upscaled_images\test\surprised\im613_4.png
# upscaled_images\test\surprised\im614_4.png
# upscaled_images\test\surprised\im615_4.png
# upscaled_images\test\surprised\im616_4.png
# upscaled_images\test\surprised\im617_4.png
# upscaled_images\test\surprised\im618_4.png
# upscaled_images\test\surprised\im619_4.png
# upscaled_images\test\surprised\im620_4.png
# upscaled_images\test\surprised\im621_4.png
# upscaled_images\test\surprised\im622_4.png
# upscaled_images\test\surprised\im623_4.png
# upscaled_images\test\surprised\im624_4.png
# upscaled_images\test\surprised\im625_4.png
# upscaled_images\test\surprised\im626_4.png
# upscaled_images\test\surprised\im627_4.png
# upscaled_images\test\surprised\im628_4.png
# upscaled_images\test\surprised\im629_4.png
# upscaled_images\test\surprised\im630_4.png
# upscaled_images\test\surprised\im631_4.png
# upscaled_images\test\surprised\im632_4.png
# upscaled_images\test\surprised\im633_4.png
# upscaled_images\test\surprised\im634_4.png
# upscaled_images\test\surprised\im635_4.png
# upscaled_images\test\surprised\im636_4.png
# upscaled_images\test\surprised\im637_4.png
# upscaled_images\test\surprised\im638_4.png
# upscaled_images\test\surprised\im639_4.png
# upscaled_images\test\surprised\im640_4.png
# upscaled_images\test\surprised\im641_4.png
# upscaled_images\test\surprised\im642_4.png
# upscaled_images\test\surprised\im643_4.png
# upscaled_images\test\surprised\im644_4.png
# upscaled_images\test\surprised\im645_4.png
# upscaled_images\test\surprised\im646_4.png
# upscaled_images\test\surprised\im647_4.png
# upscaled_images\test\surprised\im648_4.png
# upscaled_images\test\surprised\im649_4.png
# upscaled_images\test\surprised\im650_4.png
# upscaled_images\test\surprised\im651_4.png
# upscaled_images\test\surprised\im652_4.png
# upscaled_images\test\surprised\im653_4.png
# upscaled_images\test\surprised\im654_4.png
# upscaled_images\test\surprised\im655_4.png
# upscaled_images\test\surprised\im656_4.png
# upscaled_images\test\surprised\im657_4.png
# upscaled_images\test\surprised\im658_4.png
# upscaled_images\test\surprised\im659_4.png
# upscaled_images\test\surprised\im660_4.png
# upscaled_images\test\surprised\im661_4.png
# upscaled_images\test\surprised\im662_4.png
# upscaled_images\test\surprised\im663_4.png
# upscaled_images\test\surprised\im664_4.png
# upscaled_images\test\surprised\im665_4.png
# upscaled_images\test\surprised\im666_4.png
# upscaled_images\test\surprised\im667_4.png
# upscaled_images\test\surprised\im668_4.png
# upscaled_images\test\surprised\im669_4.png
# upscaled_images\test\surprised\im670_4.png
# upscaled_images\test\surprised\im671_4.png
# upscaled_images\test\surprised\im672_4.png
# upscaled_images\test\surprised\im673_4.png
# upscaled_images\test\surprised\im674_4.png
# upscaled_images\test\surprised\im675_4.png
# upscaled_images\test\surprised\im676_4.png
# upscaled_images\test\surprised\im677_4.png
# upscaled_images\test\surprised\im678_4.png
# upscaled_images\test\surprised\im679_4.png
# upscaled_images\test\surprised\im680_4.png
# upscaled_images\test\surprised\im681_4.png
# upscaled_images\test\surprised\im682_4.png
# upscaled_images\test\surprised\im683_4.png
# upscaled_images\test\surprised\im684_4.png
# upscaled_images\test\surprised\im685_4.png
# upscaled_images\test\surprised\im686_4.png
# upscaled_images\test\surprised\im687_4.png
# upscaled_images\test\surprised\im688_4.png
# upscaled_images\test\surprised\im689_4.png
# upscaled_images\test\surprised\im690_4.png
# upscaled_images\test\surprised\im691_4.png
# upscaled_images\test\surprised\im692_4.png
# upscaled_images\test\surprised\im693_4.png
# upscaled_images\test\surprised\im694_4.png
# upscaled_images\test\surprised\im695_4.png
# upscaled_images\test\surprised\im696_4.png
# upscaled_images\test\surprised\im697_4.png
# upscaled_images\test\surprised\im698_4.png
# upscaled_images\test\surprised\im699_4.png
# upscaled_images\test\surprised\im700_4.png
# upscaled_images\test\surprised\im701_4.png
# upscaled_images\test\surprised\im702_4.png
# upscaled_images\test\surprised\im703_4.png
# upscaled_images\test\surprised\im704_4.png
# upscaled_images\test\surprised\im705_4.png
# upscaled_images\test\surprised\im706_4.png
# upscaled_images\test\surprised\im707_4.png
# upscaled_images\test\surprised\im708_4.png
# upscaled_images\test\surprised\im709_4.png
# upscaled_images\test\surprised\im710_4.png
# upscaled_images\test\surprised\im711_4.png
# upscaled_images\test\surprised\im712_4.png
# upscaled_images\test\surprised\im713_4.png
# upscaled_images\test\surprised\im714_4.png
# upscaled_images\test\surprised\im715_4.png
# upscaled_images\test\surprised\im716_4.png
# upscaled_images\test\surprised\im717_4.png
# upscaled_images\test\surprised\im718_4.png
# upscaled_images\test\surprised\im719_4.png
# upscaled_images\test\surprised\im720_4.png
# upscaled_images\test\surprised\im721_4.png
# upscaled_images\test\surprised\im722_4.png
# upscaled_images\test\surprised\im723_4.png
# upscaled_images\test\surprised\im724_4.png
# upscaled_images\test\surprised\im725_4.png
# upscaled_images\test\surprised\im726_4.png
# upscaled_images\test\surprised\im727_4.png
# upscaled_images\test\surprised\im728_4.png
# upscaled_images\test\surprised\im729_4.png
# upscaled_images\test\surprised\im730_4.png
# upscaled_images\test\surprised\im731_4.png
# upscaled_images\test\surprised\im732_4.png
# upscaled_images\test\surprised\im733_4.png
# upscaled_images\test\surprised\im734_4.png
# upscaled_images\test\surprised\im735_4.png
# upscaled_images\test\surprised\im736_4.png
# upscaled_images\test\surprised\im737_4.png
# upscaled_images\test\surprised\im738_4.png
# upscaled_images\test\surprised\im739_4.png
# upscaled_images\test\surprised\im740_4.png
# upscaled_images\test\surprised\im741_4.png
# upscaled_images\test\surprised\im742_4.png
# upscaled_images\test\surprised\im743_4.png
# upscaled_images\test\surprised\im744_4.png
# upscaled_images\test\surprised\im745_4.png
# upscaled_images\test\surprised\im746_4.png
# upscaled_images\test\surprised\im747_4.png
# upscaled_images\test\surprised\im748_4.png
# upscaled_images\test\surprised\im749_4.png
# upscaled_images\test\surprised\im750_4.png
# upscaled_images\test\surprised\im751_4.png
# upscaled_images\test\surprised\im752_4.png
# upscaled_images\test\surprised\im753_4.png
# upscaled_images\test\surprised\im754_4.png
# upscaled_images\test\surprised\im755_4.png
# upscaled_images\test\surprised\im756_4.png
# upscaled_images\test\surprised\im757_4.png
# upscaled_images\test\surprised\im758_4.png
# upscaled_images\test\surprised\im759_4.png
# upscaled_images\test\surprised\im760_4.png
# upscaled_images\test\surprised\im761_4.png
# upscaled_images\test\surprised\im762_4.png
# upscaled_images\test\surprised\im763_4.png
# upscaled_images\test\surprised\im764_4.png
# upscaled_images\test\surprised\im765_4.png
# upscaled_images\test\surprised\im766_4.png
# upscaled_images\test\surprised\im767_4.png
# upscaled_images\test\surprised\im768_4.png
# upscaled_images\test\surprised\im769_4.png
# upscaled_images\test\surprised\im770_4.png
# upscaled_images\test\surprised\im771_4.png
# upscaled_images\test\surprised\im772_4.png
# upscaled_images\test\surprised\im773_4.png
# upscaled_images\test\surprised\im774_4.png
# upscaled_images\test\surprised\im775_4.png
# upscaled_images\test\surprised\im776_4.png
# upscaled_images\test\surprised\im777_4.png
# upscaled_images\test\surprised\im778_4.png
# upscaled_images\test\surprised\im779_4.png
# upscaled_images\test\surprised\im780_4.png
# upscaled_images\test\surprised\im781_4.png
# upscaled_images\test\surprised\im782_4.png
# upscaled_images\test\surprised\im783_4.png
# upscaled_images\test\surprised\im784_4.png
# upscaled_images\test\surprised\im785_4.png
# upscaled_images\test\surprised\im786_4.png
# upscaled_images\test\surprised\im787_4.png
# upscaled_images\test\surprised\im788_4.png
# upscaled_images\test\surprised\im789_4.png
# upscaled_images\test\surprised\im790_4.png
# upscaled_images\test\surprised\im791_4.png
# upscaled_images\test\surprised\im792_4.png
# upscaled_images\test\surprised\im793_4.png
# upscaled_images\test\surprised\im794_4.png
# upscaled_images\test\surprised\im795_4.png
# upscaled_images\test\surprised\im796_4.png
# upscaled_images\test\surprised\im797_4.png
# upscaled_images\test\surprised\im798_4.png
# upscaled_images\test\surprised\im799_4.png
# upscaled_images\test\surprised\im800_4.png
# upscaled_images\test\surprised\im801_4.png
# upscaled_images\test\surprised\im802_4.png
# upscaled_images\test\surprised\im803_4.png
# upscaled_images\test\surprised\im804_4.png
# upscaled_images\test\surprised\im805_4.png
# upscaled_images\test\surprised\im806_4.png
# upscaled_images\test\surprised\im807_4.png
# upscaled_images\test\surprised\im808_4.png
# upscaled_images\test\surprised\im809_4.png
# upscaled_images\test\surprised\im810_4.png
# upscaled_images\test\surprised\im811_4.png
# upscaled_images\test\surprised\im812_4.png
# upscaled_images\test\surprised\im813_4.png
# upscaled_images\test\surprised\im814_4.png
# upscaled_images\test\surprised\im815_4.png
# upscaled_images\test\surprised\im816_4.png
# upscaled_images\test\surprised\im817_4.png
# upscaled_images\test\surprised\im818_4.png
# upscaled_images\test\surprised\im819_4.png
# upscaled_images\test\surprised\im820_4.png
# upscaled_images\test\surprised\im821_4.png
# upscaled_images\test\surprised\im822_4.png
# upscaled_images\test\surprised\im823_4.png
# upscaled_images\test\surprised\im824_4.png
# upscaled_images\test\surprised\im825_4.png
# upscaled_images\test\surprised\im826_4.png
# upscaled_images\test\surprised\im827_4.png
# upscaled_images\test\surprised\im828_4.png
# upscaled_images\test\surprised\im829_4.png
# upscaled_images\test\surprised\im830_4.png
# 28709
# 7178
# {'angry': 1, 'disgusted': 2, 'fearful': 3, 'happy': 4, 'neutral': 5, 'sad': 6, 'surprised': 7}
# [1 1 1 ... 7 7 7]

# %% [markdown]
# ## KNN Classifier

# %%
knn = cv.ml.KNearest_create()
knn.train(x_train, cv.ml.ROW_SAMPLE, y_train)
# Out:
# 123161.96712176094

# %%
ret,result,neighbours,dist = knn.findNearest(x_test,k=2)
 
# Now we check the accuracy of classification
# For that, compare the result with test_labels and check which are wrong

# %%
def calculate_accuracy(result, y_test):
    print(result)

    matches = 0

    for i in range(0, len(result)):
        if result[i] == y_test[i]:
            matches = matches + 1

    accuracy = matches*100.0/result.size
    print( accuracy )
    return accuracy

# calculate_accuracy(result, y_test)

# %% [markdown]
# ## SGD classifier

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd = SGDClassifier(loss="hinge", penalty="elasticnet", max_iter=500)
sgd.fit(x_train, y_train)
# Out:
# SGDClassifier(max_iter=500, penalty='elasticnet')

# %%
prediction = sgd.predict(x_test)

# %%
prediction
# Out:
# array([3., 5., 6., ..., 5., 1., 7.], dtype=float32)

# %%
calculate_accuracy(prediction, y_test)
# Out:
# [3 5 1 ... 5 1 1]
# 26.316522708275286
# 26.316522708275286

# %%
calculate_accuracy(prediction, y_test)
# Out:
# [3. 5. 6. ... 5. 1. 7.]
# 30.21733073279465
# 30.21733073279465

# %% [markdown]
# ## SVC

# %%
from sklearn import svm

svc = svm.SVC(decision_function_shape='ovo')
svc.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 4
#       1 from sklearn import svm
#       3 svc = svm.SVC(decision_function_shape='ovo')
# ----> 4 svc.fit(x_train, y_train)
#       5 dec = svc.decision_function([[1]])
#       6 dec.shape[1]
#
# File c:\Users\Nevena\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Nevena\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File c:\Users\Nevena\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:329, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     315 libsvm.set_verbosity_wrap(self.verbose)
#     317 # we don't pass **self.get_params() to allow subclasses to
#     318 # add other parameters to __init__
#     319 (
#     320     self.support_,
#     321     self.support_vectors_,
#     322     self._n_support,
#     323     self.dual_coef_,
#     324     self.intercept_,
#     325     self._probA,
#     326     self._probB,
#     327     self.fit_status_,
#     328     self._num_iter,
# --> 329 ) = libsvm.fit(
#     330     X,
#     331     y,
#     332     svm_type=solver_type,
#     333     sample_weight=sample_weight,
#     334     class_weight=getattr(self, "class_weight_", np.empty(0)),
#     335     kernel=kernel,
#     336     C=self.C,
#     337     nu=self.nu,
#     338     probability=self.probability,
#     339     degree=self.degree,
#     340     shrinking=self.shrinking,
#     341     tol=self.tol,
#     342     cache_size=self.cache_size,
#     343     coef0=self.coef0,
#     344     gamma=self._gamma,
#     345     epsilon=self.epsilon,
#     346     max_iter=self.max_iter,
#     347     random_seed=random_seed,
#     348 )
#     350 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
from sklearn import svm

svc = svm.SVC(decision_function_shape='ovo')
svc.fit(x_train, y_train)
svc_pred = svc.predict(x_test)

# %%
calculate_accuracy(svc_pred, y_test)
# Out:
# [3 6 4 ... 6 1 7]
# 44.69211479520758
# 44.69211479520758

# %%
calculate_accuracy(svc_pred, y_test)
# Out:
# [3. 6. 4. ... 6. 1. 7.]
# 44.69211479520758
# 44.69211479520758

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb_pred = gnb.fit(x_train, y_train).predict(x_test)

# %%
calculate_accuracy(gnb_pred, y_test)
# Out:
# [7 6 7 ... 6 7 7]
# 22.652549456673167
# 22.652549456673167

# %%
calculate_accuracy(gnb_pred, y_test)
# Out:
# [7. 6. 7. ... 6. 7. 7.]
# 22.652549456673167
# 22.652549456673167

# %% [markdown]
# ## Decision Tree

# %%
from sklearn import tree
dt = tree.DecisionTreeClassifier()
dt = dt.fit(x_train, y_train)

dt_pred = dt.predict(x_test)

# %%
calculate_accuracy(dt_pred, y_test)
# Out:
# [4. 7. 1. ... 3. 7. 7.]
# 31.373641682920034
# 31.373641682920034

# %% [markdown]
# # Upscaled data

# %%
# svc = svm.SVC(decision_function_shape='ovo')
# svc.fit(x_train, y_train)
# svc_pred = svc.predict(x_test)

dt = tree.DecisionTreeClassifier()
dt = dt.fit(x_train, y_train)
dt_pred = dt.predict(x_test)

gnb = GaussianNB()
gnb = gnb.fit(x_train, y_train)
gnb_pred = gnb.predict(x_test)

sgd = SGDClassifier(loss="hinge", penalty="elasticnet", max_iter=500)
sgd.fit(x_train, y_train)
sgd_pred = sgd.predict(y_test)

# %%
# calculate_accuracy(svc_pred, y_test)
calculate_accuracy(dt_pred, y_test)
calculate_accuracy(gnb_pred, y_test)
calculate_accuracy(sgd_pred, y_test)
